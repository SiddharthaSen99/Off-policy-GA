# %%
import gym
import numpy as np
import torch
import matplotlib.pyplot as plt
import time

# %%
from gym.wrappers import Monitor

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import math
import copy
from torch.distributions import Categorical
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
    
    def clear_memory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, n_latent_var):
        super(ActorCritic, self).__init__()

        # actor
        self.action_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, action_dim),
                nn.Softmax(dim=-1)
                )
        
        # critic
        self.value_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, 1)
                )
    ##Changed this part    
    def forward(self, inputs):
            x = self.action_layer(inputs)
            return x
    
    def act(self, state, memory):
        state = torch.from_numpy(state).float().to(device) 
        action_probs = self.action_layer(state)
        dist = Categorical(action_probs)
        action = dist.sample()
        
        memory.states.append(state)
        memory.actions.append(action)
        memory.logprobs.append(dist.log_prob(action))
        
        return action.item()
    
    def evaluate(self, state, action):
        action_probs = self.action_layer(state)
        dist = Categorical(action_probs)
        
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        
        state_value = self.value_layer(state)
        
        return action_logprobs, torch.squeeze(state_value), dist_entropy

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = ActorCritic(state_dim, action_dim, n_latent_var).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr, betas=betas)
        self.policy_old = ActorCritic(state_dim, action_dim, n_latent_var).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()
    
    def update(self, memory):   
        # Monte Carlo estimate of state rewards:
        rewards = []
        surr_loss = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards).to(device)
        #print(rewards)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        #print("Rewardsd Mean: ") 
        #print(rewards.mean())
        # convert list to tensor
        old_states = torch.stack(memory.states).to(device).detach()
        old_actions = torch.stack(memory.actions).to(device).detach()
        old_logprobs = torch.stack(memory.logprobs).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evaluating old actions and values :
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)
            
            # Finding the ratio (pi_theta / pi_theta__old):
            ratios = torch.exp(logprobs - old_logprobs.detach())
            print("State Values : ", state_values.detach())
            # Finding Surrogate Loss:
            advantages = rewards - state_values.detach()
            print("Advantages : ", advantages)
            
            surr1 = ratios * advantages
            #surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            #loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            #surr_loss.append(loss)
            print("Surrogate Loss: ", surr1)
            print("Surrogate Loss Mean : ", surr1.mean())
            print("Surrogate Loss Absolute Value : ", torch.abs(surr1.mean()))
            # take gradient step
            #self.optimizer.zero_grad()
            #surr1.mean().backward()
            #self.optimizer.step()
            
                  
        # Copy new weights into old policy:       
        self.policy_old.load_state_dict(self.policy.state_dict())
        #print("Surrogate Loss Mean: ",surr1.mean())
        return torch.abs(surr1.mean())

# %%
solved_reward = 30         # stop training if avg_reward > solved_reward
log_interval = 100           # print avg reward in the interval
max_episodes = 1000        # max training episodes
max_timesteps = 30         # max timesteps in one episode
n_latent_var = 64           # number of variables in hidden layer
update_timestep = 2000      # update policy every n timesteps
lr = 0.002
betas = (0.9, 0.999)
gamma = 0.99                # discount factor
K_epochs = 1                # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
random_seed = None
render = False

# %%
env = gym.make('LunarLander-v2')

# %%
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
print("State Dimension ", state_dim, "\t Action Dimension ", action_dim)
# Out:
# State Dimension  8 	 Action Dimension  4

# %%
def return_random_agents(num_agents):
    
    agents = []
    for _ in range(num_agents):
        ##Change this part
        agent = ActorCritic(state_dim, action_dim, n_latent_var).to(device)
        
        for param in agent.parameters():
            param.requires_grad = False
         ##Commented this part   
        #init_weights(agent)
        agents.append(agent)
        
        
    return agents

# %% [markdown]
# #### I tried to change this function

# %%
def run_agents(agents):
    
    reward_agents = []
    total_loss = []
    env_name = "LunarLander-v2"
    env = gym.make('LunarLander-v2')
    if random_seed:
        torch.manual_seed(random_seed)
        env.seed(random_seed)
    
    memory = Memory()
    ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)
    print(lr,betas)
    
    # logging variables
    running_reward = 0
    avg_length = 0
    timestep = 0
    surri=0
    s1 = []
    s2 = 0
    s_temp = []
    surr_actual = []
    
    # training loop
    #for agent in agents:
    for i_episode in range(1, max_episodes+1):
        #agent.eval()
        state = env.reset()
        for t in range(max_timesteps):
            timestep += 1
            
            # Running policy_old:
            action = ppo.policy_old.act(state, memory)
            state, reward, done, _ = env.step(action)
            
            # Saving reward and is_terminal:
            memory.rewards.append(reward)
            memory.is_terminals.append(done)
            
            # update if its time
            if timestep % update_timestep == 0:
                surri=ppo.update(memory)
                #print("Returned Surrogate Loss ", surri)
                memory.clear_memory()
                timestep = 0
            
            running_reward += reward
            if render:
                env.render()
            if done:
                break
                
        avg_length += t
        
        # stop training if avg_reward > solved_reward
        if running_reward > (log_interval*solved_reward):
            print("########## Solved! ##########")
            torch.save(ppo.policy.state_dict(), './PPO_{}.pth'.format(env_name))
            break
            
        # logging
        if i_episode % log_interval == 0:
            avg_length = int(avg_length/log_interval)
            running_reward = int((running_reward/log_interval))
            print(' Episode {} '.format(i_episode))
            running_reward = 0
            avg_length = 0
        s1.append(surri)
        #surr_mean = torch.mean(torch.stack(surr_actual))    
    s1 = [i for i in s1 if i != 0]
    #print(torch.mean(torch.stack(s1)))
    #print("\n")
            
    #print(total_loss)
    return torch.mean(torch.stack(s1))

# %%
def return_average_score(agent, runs):
    #score = 0.
    #for i in range(runs):
    #print(run_agents([agent]))
    score = run_agents([agent])
    return score#/runs

# %% [markdown]
# #### <--Till Now Only worked -->

# %%
def run_agents_n_times(agents, runs):
    avg_score = []
    for agent in agents:
        avg_score.append(return_average_score(agent,runs))
    return avg_score

# %%
def mutate(agent):

    child_agent = copy.deepcopy(agent)
    
    mutation_power = 0.02 #hyper-parameter, set from https://arxiv.org/pdf/1712.06567.pdf
            
    for param in child_agent.parameters():
    
        if(len(param.shape)==4): #weights of Conv2D

            for i0 in range(param.shape[0]):
                for i1 in range(param.shape[1]):
                    for i2 in range(param.shape[2]):
                        for i3 in range(param.shape[3]):
                            
                            param[i0][i1][i2][i3]+= mutation_power * np.random.randn()
                                
                                    

        elif(len(param.shape)==2): #weights of linear layer
            for i0 in range(param.shape[0]):
                for i1 in range(param.shape[1]):
                    
                    param[i0][i1]+= mutation_power * np.random.randn()
                        

        elif(len(param.shape)==1): #biases of linear layer or conv layer
            for i0 in range(param.shape[0]):
                
                param[i0]+=mutation_power * np.random.randn()

    return child_agent

# %%
def return_children(agents, sorted_parent_indexes, elite_index):
    
    children_agents = []
    
    #first take selected parents from sorted_parent_indexes and generate N-1 children
    for i in range(len(agents)-1):
        
        selected_agent_index = sorted_parent_indexes[np.random.randint(len(sorted_parent_indexes))]
        children_agents.append(mutate(agents[selected_agent_index]))

    #now add one elite
    elite_child = add_elite(agents, sorted_parent_indexes, elite_index)
    children_agents.append(elite_child)
    elite_index=len(children_agents)-1 #it is the last one
    
    return children_agents, elite_index

# %%
def add_elite(agents, sorted_parent_indexes, elite_index=None, only_consider_top_n=10):
    
    candidate_elite_index = sorted_parent_indexes[:only_consider_top_n]
    
    if(elite_index is not None):
        candidate_elite_index = np.append(candidate_elite_index,[elite_index])
        
    top_score = None
    top_elite_index = None
    
    for i in candidate_elite_index:
        score = return_average_score(agents[i],runs=5)
        print("Score for elite i ", i, " is ", score)
        
        if(top_score is None):
            top_score = score
            top_elite_index = i
        elif(score > top_score):
            top_score = score
            top_elite_index = i
            
    print("Elite selected with index ",top_elite_index, " and score", top_score)
    
    child_agent = copy.deepcopy(agents[top_elite_index])
    return child_agent

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    return np.exp(x) / np.sum(np.exp(x), axis=0)

# %%
game_actions = 2 #2 actions possible: left or right

#disable gradients as we will not use them
#torch.set_grad_enabled(False)

# initialize N number of agents
num_agents = 10
agents = return_random_agents(num_agents)

# How many top agents to consider as parents
top_limit = 3

# run evolution until X generations
generations = 5

elite_index = None

for generation in range(generations):

    # return rewards of agents
    losses = run_agents_n_times(agents, 1) #return average of 3 runs

    # sort by rewards
    sorted_parent_indexes = np.argsort(losses)[::-1][:top_limit]#reverses and gives top values (argsort sorts by ascending by default) https://stackoverflow.com/questions/16486252/is-it-possible-to-use-argsort-in-descending-order
    print("\n Sorting Parent Indexes: ",sorted_parent_indexes)
    print(" Data Type: ", type(sorted_parent_indexes))
    print("Sorting Completed")
    print("Selecting Top Parents")
    
    top_losses = []
    for best_parent in sorted_parent_indexes:
        top_losses.append(losses[best_parent])
   
    print("\n \n Generation ", generation, " | Mean Losses: ", torch.mean(torch.stack(losses)), " | Mean of top 5: ",torch.mean(torch.stack(top_losses[:5])))
    
    print("Top ",top_limit," scores", sorted_parent_indexes)
    print("Rewards for top: ",top_losses)
    
    # setup an empty list for containing children agents
    children_agents, elite_index = return_children(agents, sorted_parent_indexes, elite_index)

    # kill all agents, and replace them with their children
    agents = children_agents
# Out:
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.0111, -0.0111, -0.0115,  ..., -0.0194, -0.0214, -0.0215])
# Advantages :  tensor([0.0808, 0.0804, 0.0756,  ..., 2.3533, 2.3395, 2.3178])
# Surrogate Loss:  tensor([0.0808, 0.0804, 0.0756,  ..., 2.3533, 2.3395, 2.3178],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0135, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0135, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.0233, -0.0257, -0.0230,  ..., -0.0164, -0.0129, -0.0123])
# Advantages :  tensor([0.4348, 0.3742, 0.4090,  ..., 2.7026, 2.6727, 2.7633])
# Surrogate Loss:  tensor([0.4348, 0.3742, 0.4090,  ..., 2.7026, 2.6727, 2.7633],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0129, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0129, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0111, -0.0130, -0.0118,  ..., -0.0213, -0.0210, -0.0228])
# Advantages :  tensor([-0.5446, -0.5164, -0.3781,  ...,  2.3196,  2.3597,  2.3849])
# Surrogate Loss:  tensor([-0.5446, -0.5164, -0.3781,  ...,  2.3196,  2.3597,  2.3849],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0130, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0130, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.0108, -0.0112, -0.0109,  ..., -0.0128, -0.0143, -0.0161])
# Advantages :  tensor([-0.1821, -0.2120, -0.2185,  ...,  2.9854,  3.0461,  3.1105])
# Surrogate Loss:  tensor([-0.1821, -0.2120, -0.2185,  ...,  2.9854,  3.0461,  3.1105],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0131, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0131, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.0163, -0.0155, -0.0170,  ..., -0.0053, -0.0058, -0.0063])
# Advantages :  tensor([0.3551, 0.4119, 0.4764,  ..., 2.8972, 2.9610, 3.0253])
# Surrogate Loss:  tensor([0.3551, 0.4119, 0.4764,  ..., 2.8972, 2.9610, 3.0253],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0145, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0145, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0091, -0.0104, -0.0112,  ..., -0.0075, -0.0087, -0.0082])
# Advantages :  tensor([-0.7571, -0.7871, -0.8981,  ...,  2.8125,  2.9201,  3.0052])
# Surrogate Loss:  tensor([-0.7571, -0.7871, -0.8981,  ...,  2.8125,  2.9201,  3.0052],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0134, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0134, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor
grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([-0.0416, -0.0408, -0.0384,  ..., -0.0395, -0.0383, -0.0407])
# Advantages :  tensor([-1.1640, -1.2188, -1.1931,  ...,  2.7619,  2.8328,  2.6920])
# Surrogate Loss:  tensor([-1.1640, -1.2188, -1.1931,  ...,  2.7619,  2.8328,  2.6920],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0439, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0439, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0411, -0.0410, -0.0385,  ..., -0.0336, -0.0340, -0.0355])
# Advantages :  tensor([-2.0076, -2.0664, -2.0186,  ...,  3.0161,  3.0717,  3.1079])
# Surrogate Loss:  tensor([-2.0076, -2.0664, -2.0186,  ...,  3.0161,  3.0717,  3.1079],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0462, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0462, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([-0.0313, -0.0286, -0.0257,  ..., -0.0270, -0.0278, -0.0267])
# Advantages :  tensor([1.3970, 1.4436, 1.5029,  ..., 2.8297, 2.7840, 2.8110])
# Surrogate Loss:  tensor([1.3970, 1.4436, 1.5029,  ..., 2.8297, 2.7840, 2.8110],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0471, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0471, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([-0.0256, -0.0237, -0.0260,  ..., -0.0698, -0.0683, -0.0671])
# Advantages :  tensor([-0.3171, -0.2810, -0.4384,  ...,  3.1215,  3.1971,  3.2959])
# Surrogate Loss:  tensor([-0.3171, -0.2810, -0.4384,  ...,  3.1215,  3.1971,  3.2959],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0497, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0497, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0659, -0.0642, -0.0619,  ..., -0.0581, -0.0604, -0.0575])
# Advantages :  tensor([-2.9403, -2.8735, -2.8451,  ...,  3.6249,  3.7316,  3.8052])
# Surrogate Loss:  tensor([-2.9403, -2.8735, -2.8451,  ...,  3.6249,  3.7316,  3.8052],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0455, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0455, grad_fn=<AbsBackward>)
#  Episode 1000
# 0.002 (0.9, 0.999)
# State Values :  tensor([0.2467, 0.2502, 0.2537,  ..., 0.1863, 0.1864, 0.1840])
# Advantages :  tensor([1.1847, 1.0977, 0.9948,  ..., 2.4750, 2.5493, 2.6847])
# Surrogate Loss:  tensor([1.1847, 1.0977, 0.9948,  ..., 2.4750, 2.5493, 2.6847],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3007, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3007, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([0.1842, 0.1828, 0.1831,  ..., 0.3720, 0.3696, 0.3678])
# Advantages :  tensor([-0.9906, -1.0086, -0.9676,  ...,  2.1486,  2.1569,  2.1649])
# Surrogate Loss:  tensor([-0.9906, -1.0086, -0.9676,  ...,  2.1486,  2.1569,  2.1649],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3002, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3002, grad_fn=<AbsBackward>)
# State Values :  tensor([0.3681, 0.3684, 0.3665,  ..., 0.2599, 0.2601, 0.2602])
# Advantages :  tensor([1.2488, 1.2786, 1.2711,  ..., 2.3379, 2.4144, 2.4907])
# Surrogate Loss:  tensor([1.2488, 1.2786, 1.2711,  ..., 2.3379, 2.4144, 2.4907],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.2775, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2775, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([0.2495, 0.2476, 0.2500,  ..., 0.3946, 0.3928, 0.3933])
# Advantages :  tensor([-0.2877, -0.2289, -0.2322,  ...,  2.0631,  2.1451,  2.1572])
# Surrogate Loss:  tensor([-0.2877, -0.2289, -0.2322,  ...,  2.0631,  2.1451,  2.1572],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3024, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3024, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([0.3898, 0.3904, 0.3890,  ..., 0.2059, 0.2045, 0.2011])
# Advantages :  tensor([0.8560, 0.8785, 0.9322,  ..., 3.5402, 3.5820, 3.5353])
# Surrogate Loss:  tensor([0.8560, 0.8785, 0.9322,  ..., 3.5402, 3.5820, 3.5353],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.2978, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2978, grad_fn=<AbsBackward>)
# State Values :  tensor([0.2020, 0.2028, 0.1984,  ..., 0.4017, 0.4017, 0.4015])
# Advantages :  tensor([0.1401, 0.0928, 0.1292,  ..., 2.1348, 2.2535, 2.3829])
# Surrogate Loss:  tensor([0.1401, 0.0928, 0.1292,  ..., 2.1348, 2.2535, 2.3829],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3116, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3116, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([0.2828, 0.2853, 0.2868,  ..., 0.2952, 0.2972, 0.2969])
# Advantages :  tensor([-0.2535, -0.2549, -0.2515,  ...,  2.9245,  3.0485,  3.2231])
# Surrogate Loss:  tensor([-0.2535, -0.2549, -0.2515,  ...,  2.9245,  3.0485,  3.2231],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3087, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3087, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([0.2970, 0.2971, 0.3015,  ..., 0.2310, 0.2273, 0.2274])
# Advantages :  tensor([-0.1968, -0.1223, -0.0478,  ...,  2.2951,  2.3825,  2.3102])
# Surrogate Loss:  tensor([-0.1968, -0.1223, -0.0478,  ...,  2.2951,  2.3825,  2.3102],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3081, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3081, grad_fn=<AbsBackward>)
# State Values :  tensor([0.2268, 0.2243, 0.2213,  ..., 0.3556, 0.3530, 0.3529])
# Advantages :  tensor([-0.8426, -0.7881, -0.8484,  ...,  3.4429,  3.4188,  3.5534])
# Surrogate Loss:  tensor([-0.8426, -0.7881, -0.8484,  ...,  3.4429,  3.4188,  3.5534],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.2983, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2983, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([0.3540, 0.3514, 0.3495,  ..., 0.2606, 0.2609, 0.2635])
# Advantages :  tensor([0.1989, 0.1947, 0.1920,  ..., 3.4173, 3.5115, 3.5712])
# Surrogate Loss:  tensor([0.1989, 0.1947, 0.1920,  ..., 3.4173, 3.5115, 3.5712],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3001, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3001, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([0.2635, 0.2660, 0.2655,  ..., 0.3650, 0.3680, 0.3661])
# Advantages :  tensor([0.5159, 0.5286, 0.5683,  ..., 3.4035, 3.4809, 3.5304])
# Surrogate Loss:  tensor([0.5159, 0.5286, 0.5683,  ..., 3.4035, 3.4809, 3.5304],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3059, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3059, grad_fn=<AbsBackward>)
# State Values :  tensor([0.3648, 0.3651, 0.3655,  ..., 0.3065, 0.3055, 0.3064])
# Advantages :  tensor([-2.0009, -2.0288, -2.0536,  ...,  2.5731,  2.6869,  2.6705])
# Surrogate Loss:  tensor([-2.0009, -2.0288, -2.0536,  ...,  2.5731,  2.6869,  2.6705],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3085, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3085, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([0.2151, 0.2126, 0.2089,  ..., 0.3035, 0.3059, 0.3057])
# Advantages :  tensor([-2.5013, -2.5682, -2.6220,  ...,  2.5054,  2.6014,  2.6940])
# Surrogate Loss:  tensor([-2.5013, -2.5682, -2.6220,  ...,  2.5054,  2.6014,  2.6940],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.2924, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2924, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([0.3076, 0.3071, 0.3067,  ..., 0.1977, 0.1954, 0.1970])
# Advantages :  tensor([-0.3029, -0.2500, -0.1982,  ...,  2.1445,  2.2137,  2.2279])
# Surrogate Loss:  tensor([-0.3029, -0.2500, -0.1982,  ...,  2.1445,  2.2137,  2.2279],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.2975, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2975, grad_fn=<AbsBackward>)
# State Values :  tensor([0.1948, 0.1966, 0.1929,  ..., 0.2563, 0.2563, 0.2564])
# Advantages :  tensor([-0.6911, -0.7117, -0.6977,  ...,  2.5140,  2.5261,  2.5440])
# Surrogate Loss:  tensor([-0.6911, -0.7117, -0.6977,  ...,  2.5140,  2.5261,  2.5440],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.3076, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.3076, grad_fn=<AbsBackward>)
#  Episode 1000
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.1696, -0.1692, -0.1716,  ..., -0.1534, -0.1578, -0.1574])
# Advantages :  tensor([-0.1863, -0.2158, -0.1818,  ...,  2.4295,  2.5100,  2.6339])
# Surrogate Loss:  tensor([-0.1863, -0.2158, -0.1818,  ...,  2.4295,  2.5100,  2.6339],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1618, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1618, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.1620, -0.1669, -0.1717,  ..., -0.1361, -0.1394, -0.1441])
# Advantages :  tensor([-1.9923, -1.8792, -1.7520,  ...,  3.8531,  3.8566,  3.9428])
# Surrogate Loss:  tensor([-1.9923, -1.8792, -1.7520,  ...,  3.8531,  3.8566,  3.9428],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1650, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1650, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.1419, -0.1463, -0.1484,  ..., -0.1258, -0.1244, -0.1266])
# Advantages :  tensor([-0.4341, -0.4037, -0.4503,  ...,  2.8608,  2.9341,  3.0139])
# Surrogate Loss:  tensor([-0.4341, -0.4037, -0.4503,  ...,  2.8608,  2.9341,  3.0139],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1617, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1617, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.1588, -0.1546, -0.1562,  ..., -0.1676, -0.1719, -0.1738])
# Advantages :  tensor([ 0.0819,  0.0075, -0.0437,  ...,  4.0044,  4.1518,  4.1922])
# Surrogate Loss:  tensor([ 0.0819,  0.0075, -0.0437,  ...,  4.0044,  4.1518,  4.1922],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1540, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1540, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.1779, -0.1794, -0.1815,  ..., -0.1252, -0.1281, -0.1303])
# Advantages :  tensor([2.1390, 2.1533, 2.1795,  ..., 2.9143, 2.8822, 2.8480])
# Surrogate Loss:  tensor([2.1390, 2.1533, 2.1795,  ..., 2.9143, 2.8822, 2.8480],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1567, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1567, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.1343, -0.1372, -0.1360,  ..., -0.1694, -0.1713, -0.1728])
# Advantages :  tensor([-1.8890, -1.8870, -1.8570,  ...,  3.2790,  3.3301,  3.3864])
# Surrogate Loss:  tensor([-1.8890, -1.8870, -1.8570,  ...,  3.2790,  3.3301,  3.3864],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1611, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1611, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([-0.1171, -0.1189, -0.1209,  ..., -0.1821, -0.1848, -0.1885])
# Advantages :  tensor([-1.6688e-03, -1.2735e-01, -2.5068e-01,  ...,  3.2070e+00,
#          3.2903e+00,  3.3902e+00])
# Surrogate Loss:  tensor([-1.6688e-03, -1.2735e-01, -2.5068e-01,  ...,  3.2070e+00,
#          3.2903e+00,  3.3902e+00], grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1552, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1552, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor

#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1314, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1314, grad_fn=<AbsBackward>)
# State Values :  tensor([0.0944, 0.0924, 0.0924,  ..., 0.1751, 0.1741, 0.1751])
# Advantages :  tensor([-0.9317, -0.7696, -0.7673,  ...,  2.3232,  2.4028,  2.4480])
# Surrogate Loss:  tensor([-0.9317, -0.7696, -0.7673,  ...,  2.3232,  2.4028,  2.4480],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1271, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1271, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([0.0557, 0.0565, 0.0572,  ..., 0.1683, 0.1675, 0.1693])
# Advantages :  tensor([-0.2580, -0.2406, -0.2122,  ...,  2.8221,  2.8667,  2.9767])
# Surrogate Loss:  tensor([-0.2580, -0.2406, -0.2122,  ...,  2.8221,  2.8667,  2.9767],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1319, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1319, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([0.1684, 0.1670, 0.1654,  ..., 0.0985, 0.1021, 0.1050])
# Advantages :  tensor([-0.7675, -0.7488, -0.7750,  ...,  3.6424,  3.5528,  3.4752])
# Surrogate Loss:  tensor([-0.7675, -0.7488, -0.7750,  ...,  3.6424,  3.5528,  3.4752],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1299, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1299, grad_fn=<AbsBackward>)
# State Values :  tensor([0.1081, 0.1116, 0.1117,  ..., 0.0802, 0.0772, 0.0789])
# Advantages :  tensor([0.4404, 0.2636, 0.2128,  ..., 4.2301, 4.4518, 4.4934])
# Surrogate Loss:  tensor([0.4404, 0.2636, 0.2128,  ..., 4.2301, 4.4518, 4.4934],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1244, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1244, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([0.1298, 0.1297, 0.1312,  ..., 0.1608, 0.1595, 0.1612])
# Advantages :  tensor([1.1823, 1.0993, 1.0414,  ..., 2.4979, 2.5986, 2.5987])
# Surrogate Loss:  tensor([1.1823, 1.0993, 1.0414,  ..., 2.4979, 2.5986, 2.5987],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1266, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1266, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([0.1629, 0.1628, 0.1620,  ..., 0.0864, 0.0860, 0.0839])
# Advantages :  tensor([0.2928, 0.2096, 0.3481,  ..., 3.7462, 3.8213, 3.7682])
# Surrogate Loss:  tensor([0.2928, 0.2096, 0.3481,  ..., 3.7462, 3.8213, 3.7682],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1235, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1235, grad_fn=<AbsBackward>)
# State Values :  tensor([0.0863, 0.0853, 0.0842,  ..., 0.1135, 0.1138, 0.1124])
# Advantages :  tensor([-0.0798, -0.0377, -0.1194,  ...,  3.2208,  3.2617,  3.3658])
# Surrogate Loss:  tensor([-0.0798, -0.0377, -0.1194,  ...,  3.2208,  3.2617,  3.3658],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1279, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1279, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([0.1030, 0.1037, 0.1054,  ..., 0.1406, 0.1398, 0.1386])
# Advantages :  tensor([1.8453, 1.8807, 1.8877,  ..., 2.8030, 2.7469, 2.6475])
# Surrogate Loss:  tensor([1.8453, 1.8807, 1.8877,  ..., 2.8030, 2.7469, 2.6475],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1316, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1316, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([0.1372, 0.1371, 0.1389,  ..., 0.1457, 0.1436, 0.1410])
# Advantages :  tensor([-1.5967, -1.5974, -1.5834,  ...,  2.9706,  3.0257,  2.8527])
# Surrogate Loss:  tensor([-1.5967, -1.5974, -1.5834,  ...,  2.9706,  3.0257,  2.8527],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1308, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1308, grad_fn=<AbsBackward>)
# State Values :  tensor([0.1408, 0.1385, 0.1383,  ..., 0.0977, 0.0960, 0.0925])
# Advantages :  tensor([0.2053, 0.0284, 0.0669,  ..., 2.2849, 2.3717, 2.3331])
# Surrogate Loss:  tensor([0.2053, 0.0284, 0.0669,  ..., 2.2849, 2.3717, 2.3331],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1281, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1281, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([0.1825, 0.1828, 0.1811,  ..., 0.0852, 0.0829, 0.0812])
# Advantages :  tensor([-0.9626, -0.9658, -0.9982,  ...,  1.9927,  2.0796,  2.1790])
# Surrogate Loss:  tensor([-0.9626, -0.9658, -0.9982,  ...,  1.9927,  2.0796,  2.1790],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1357, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1357, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([0.0785, 0.0784, 0.0782,  ..., 0.0683, 0.0691, 0.0711])
# Advantages :  tensor([0.2565, 0.3110, 0.3780,  ..., 3.7095, 3.7409, 3.7397])
# Surrogate Loss:  tensor([0.2565, 0.3110, 0.3780,  ..., 3.7095, 3.7409, 3.7397],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1283, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1283, grad_fn=<AbsBackward>)
# State Values :  tensor([0.0750, 0.0750, 0.0783,  ..., 0.0795, 0.0775, 0.0778])
# Advantages :  tensor([-1.7807, -1.7861, -1.8659,  ...,  2.5569,  2.5849,  2.6353])
# Surrogate Loss:  tensor([-1.7807, -1.7861, -1.8659,  ...,  2.5569,  2.5849,  2.6353],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.1307, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1307, grad_fn=<AbsBackward>)
#  Episode 1000
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.0572, -0.0548, -0.0523,  ..., -0.0871, -0.0845, -0.0785])
# Advantages :  tensor([0.3233, 0.2755, 0.2396,  ..., 4.4110, 4.4421, 4.4262])
# Surrogate Loss:  tensor([0.3233, 0.2755, 0.2396,  ..., 4.4110, 4.4421, 4.4262],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0449, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0449, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.0760, -0.0735, -0.0710,  ..., -0.0326, -0.0343, -0.0356])
# Advantages :  tensor([0.4466, 0.4487, 0.4528,  ..., 3.0909, 3.1735, 3.1850])
# Surrogate Loss:  tensor([0.4466, 0.4487, 0.4528,  ..., 3.0909, 3.1735, 3.1850],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0457, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0457, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0376, -0.0391, -0.0366,  ..., -0.0543, -0.0551, -0.0557])
# Advantages :  tensor([1.0549, 0.9959, 0.9846,  ..., 3.9031, 4.0811, 4.0707])
# Surrogate Loss:  tensor([1.0549, 0.9959, 0.9846,  ..., 3.9031, 4.0811, 4.0707],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0360, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0360, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.1377, -0.1346, -0.1281,  ..., -0.0254, -0.0230, -0.0207])
# Advantages :  tensor([0.1984, 0.1493, 0.0613,  ..., 3.2923, 3.3181, 3.3457])
# Surrogate Loss:  tensor([0.1984, 0.1493, 0.0613,  ..., 3.2923, 3.3181, 3.3457],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0415, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0415, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.0149, -0.0089, -0.0029,  ..., -0.0037, -0.0056, -0.0069])
# Advantages :  tensor([0.1295, 0.1711, 0.2236,  ..., 2.8491, 2.9148, 3.0187])
# Surrogate Loss:  tensor([0.1295, 0.1711, 0.2236,  ..., 2.8491, 2.9148, 3.0187],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.

#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0432, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0432, grad_fn=<AbsBackward>)
#  Episode 1000
# 0.002 (0.9, 0.999)
# State Values :  tensor([0.0053, 0.0067, 0.0021,  ..., 0.0117, 0.0100, 0.0107])
# Advantages :  tensor([-2.7154, -2.7290, -2.7139,  ...,  3.3048,  3.3110,  3.3000])
# Surrogate Loss:  tensor([-2.7154, -2.7290, -2.7139,  ...,  3.3048,  3.3110,  3.3000],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0058, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0058, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([ 0.0088,  0.0066,  0.0044,  ..., -0.0071, -0.0086, -0.0106])
# Advantages :  tensor([-0.2621, -0.2801, -0.2738,  ...,  2.4645,  2.4693,  2.4719])
# Surrogate Loss:  tensor([-0.2621, -0.2801, -0.2738,  ...,  2.4645,  2.4693,  2.4719],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0105, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0105, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0124, -0.0138, -0.0149,  ...,  0.0014,  0.0089,  0.0171])
# Advantages :  tensor([-1.2353, -1.2052, -1.1670,  ...,  2.8454,  2.7434,  2.6700])
# Surrogate Loss:  tensor([-1.2353, -1.2052, -1.1670,  ...,  2.8454,  2.7434,  2.6700],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0061, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0061, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.0390, -0.0374, -0.0410,  ...,  0.0500,  0.0502,  0.0507])
# Advantages :  tensor([0.5220, 0.3912, 0.4544,  ..., 2.5576, 2.6428, 2.7319])
# Surrogate Loss:  tensor([0.5220, 0.3912, 0.4544,  ..., 2.5576, 2.6428, 2.7319],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0131, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0131, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([0.0513, 0.0516, 0.0554,  ..., 0.0166, 0.0186, 0.0175])
# Advantages :  tensor([0.0378, 0.0209, 0.0660,  ..., 3.5608, 3.6989, 3.6559])
# Surrogate Loss:  tensor([0.0378, 0.0209, 0.0660,  ..., 3.5608, 3.6989, 3.6559],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0013, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0013, grad_fn=<AbsBackward>)
# State Values :  tensor([ 0.0168,  0.0165,  0.0156,  ...,  0.0006, -0.0019, -0.0041])
# Advantages :  tensor([-1.6946, -1.7146, -1.6462,  ...,  3.0209,  3.0815,  3.1693])
# Surrogate Loss:  tensor([-1.6946, -1.7146, -1.6462,  ...,  3.0209,  3.0815,  3.1693],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0079, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0079, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([0.0115, 0.0086, 0.0052,  ..., 0.0038, 0.0026, 0.0015])
# Advantages :  tensor([-0.3362, -0.2976, -0.2413,  ...,  2.7912,  2.7868,  2.8621])
# Surrogate Loss:  tensor([-0.3362, -0.2976, -0.2413,  ...,  2.7912,  2.7868,  2.8621],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0074, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0074, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([0.0028, 0.0016, 0.0007,  ..., 0.0265, 0.0257, 0.0253])
# Advantages :  tensor([-0.2746, -0.3068, -0.2626,  ...,  2.4280,  2.4770,  2.5848])
# Surrogate Loss:  tensor([-0.2746, -0.3068, -0.2626,  ...,  2.4280,  2.4770,  2.5848],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0033, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0033, grad_fn=<AbsBackward>)
# State Values :  tensor([ 0.0245,  0.0291,  0.0283,  ..., -0.0678, -0.0715, -0.0752])
# Advantages :  tensor([-0.1217, -0.0981, -0.0741,  ...,  2.2371,  2.2976,  2.3690])
# Surrogate Loss:  tensor([-0.1217, -0.0981, -0.0741,  ...,  2.2371,  2.2976,  2.3690],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0108, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0108, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([ 0.0088,  0.0058,  0.0032,  ..., -0.0332, -0.0360, -0.0360])
# Advantages :  tensor([-0.7911, -0.7636, -0.8089,  ...,  3.2120,  3.2909,  3.2340])
# Surrogate Loss:  tensor([-0.7911, -0.7636, -0.8089,  ...,  3.2120,  3.2909,  3.2340],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0142, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0142, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([-0.0351, -0.0351, -0.0321,  ..., -0.0570, -0.0614, -0.0659])
# Advantages :  tensor([ 0.1417,  0.0753, -0.0927,  ...,  2.4106,  2.4611,  2.5122])
# Surrogate Loss:  tensor([ 0.1417,  0.0753, -0.0927,  ...,  2.4106,  2.4611,  2.5122],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(-0.0006, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0006, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0703, -0.0747, -0.0788,  ..., -0.0856, -0.0833, -0.0845])
# Advantages :  tensor([0.6462, 0.6264, 0.6475,  ..., 3.4536, 3.3269, 3.2795])
# Surrogate Loss:  tensor([0.6462, 0.6264, 0.6475,  ..., 3.4536, 3.3269, 3.2795],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0159, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0159, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([ 0.0620,  0.0601,  0.0595,  ..., -0.0316, -0.0328, -0.0311])
# Advantages :  tensor([-1.1965, -1.3039, -1.3285,  ...,  3.7982,  3.8669,  3.8145])
# Surrogate Loss:  tensor([-1.1965, -1.3039, -1.3285,  ...,  3.7982,  3.8669,  3.8145],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0080, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0080, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([-0.0278, -0.0235, -0.0197,  ...,  0.0447,  0.0428,  0.0406])
# Advantages :  tensor([-0.3750, -0.5778, -0.7339,  ...,  3.7004,  3.6452,  3.5741])
# Surrogate Loss:  tensor([-0.3750, -0.5778, -0.7339,  ...,  3.7004,  3.6452,  3.5741],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0086, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0086, grad_fn=<AbsBackward>)
# State Values :  tensor([0.0380, 0.0361, 0.0334,  ..., 0.0698, 0.0714, 0.0726])
# Advantages :  tensor([0.8218, 0.7468, 0.6010,  ..., 3.4659, 3.5315, 3.5905])
# Surrogate Loss:  tensor([0.8218, 0.7468, 0.6010,  ..., 3.4659, 3.5315, 3.5905],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0003, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0003, grad_fn=<AbsBackward>)
#  Episode 1000
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.2482, -0.2476, -0.2442,  ..., -0.2499, -0.2501, -0.2495])
# Advantages :  tensor([1.0172, 1.0439, 1.0421,  ..., 2.3200, 2.2689, 2.2316])
# Surrogate Loss:  tensor([1.0172, 1.0439, 1.0421,  ..., 2.3200, 2.2689, 2.2316],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2024, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2024, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.2510, -0.2520, -0.2526,  ..., -0.1378, -0.1353, -0.1377])
# Advantages :  tensor([0.1409, 0.2220, 0.1539,  ..., 3.5832, 3.6897, 3.6917])
# Surrogate Loss:  tensor([0.1409, 0.2220, 0.1539,  ..., 3.5832, 3.6897, 3.6917],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1933, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1933, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.1347, -0.1346, -0.1345,  ..., -0.1190, -0.1202, -0.1175])
# Advantages :  tensor([-1.6098, -1.6029, -1.5938,  ...,  2.5897,  2.6680,  2.7360])
# Surrogate Loss:  tensor([-1.6098, -1.6029, -1.5938,  ...,  2.5897,  2.6680,  2.7360],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2000, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2000, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.1972, -0.2004, -0.2008,  ..., -0.1906, -0.1899, -0.1933])
# Advantages :  tensor([-0.1611, -0.1151, -0.0229,  ...,  2.8602,  2.9528,  2.8591])
# Surrogate Loss:  tensor([-0.1611, -0.1151, -0.0229,  ...,  2.8602,  2.9528,  2.8591],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1950, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1950, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.1932, -0.1925, -0.1905,  ..., -0.2567, -0.2595, -0.2625])
# Advantages :  tensor([-0.6860, -0.6625, -0.6892,  ...,  2.5054,  2.5426,  2.5892])
# Surrogate Loss:  tensor([-0.6860, -0.6625, -0.6892,  ...,  2.5054,  2.5426,  2.5892],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1989, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1989, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2633, -0.2629, -0.2637,  ..., -0.1863, -0.1829, -0.1801])
# Advantages :  tensor([-0.2135, -0.2585, -0.1980,  ...,  3.4504,  3.5202,  3.5742])
# Surrogate Loss:  tensor([-0.2135, -0.2585, -0.1980,  ...,  3.4504,  3.5202,  3.5742],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1906, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1906, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([-0.2504, -0.2498, -0.2473,  ..., -0.2122, -0.2118, -0.2146])
# Advantages :  tensor([1.2731, 1.3092, 1.3132,  ..., 3.0644, 3.1425, 3.2508])
# Surrogate Loss:  tensor([1.2731, 1.3092, 1.3132,  ..., 3.0644, 3.1425, 3.2508],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1928, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1928, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([-0.2124, -0.2115, -0.2085,  ..., -0.2155, -0.2175, -0.2144])
# Advantages :  tensor([1.4969, 1.2949, 1.3308,  ..., 3.4617, 3.5673, 3.6068])
# Surrogate Loss:  tensor([1.4969, 1.2949, 1.3308,  ..., 3.4617, 3.5673, 3.6068],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.1861, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.1861, grad_fn=<AbsBackward>)
# ...
# State Values :  tensor([-0.0185, -0.0199, -0.0197,  ..., -0.0103, -0.0095, -0.0086])
# Advantages :  tensor([0.4055, 0.3489, 0.3291,  ..., 3.2151, 3.2204, 3.2253])
# Surrogate Loss:  tensor([0.4055, 0.3489, 0.3291,  ..., 3.2151, 3.2204, 3.2253],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0250, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0250, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([-0.0518, -0.0497, -0.0493,  ..., -0.0046, -0.0046, -0.0046])
# Advantages :  tensor([0.1810, 0.1242, 0.1122,  ..., 2.7353, 2.8238, 2.9017])
# Surrogate Loss:  tensor([0.1810, 0.1242, 0.1122,  ..., 2.7353, 2.8238, 2.9017],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0219, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0219, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([-0.0029, -0.0034, -0.0034,  ..., -0.0238, -0.0240, -0.0241])
# Advantages :  tensor([0.1706, 0.3542, 0.4219,  ..., 3.4919, 3.4052, 3.3481])
# Surrogate Loss:  tensor([0.1706, 0.3542, 0.4219,  ..., 3.4919, 3.4052, 3.3481],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0231, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0231, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0256, -0.0258, -0.0256,  ..., -0.0243, -0.0252, -0.0229])
# Advantages :  tensor([1.2805, 1.1975, 1.0940,  ..., 3.0714, 3.1531, 3.1580])
# Surrogate Loss:  tensor([1.2805, 1.1975, 1.0940,  ..., 3.0714, 3.1531, 3.1580],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0256, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0256, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([-0.0318, -0.0313, -0.0307,  ..., -0.0190, -0.0169, -0.0171])
# Advantages :  tensor([0.8001, 0.8508, 0.9064,  ..., 2.7149, 2.8460, 2.8735])
# Surrogate Loss:  tensor([0.8001, 0.8508, 0.9064,  ..., 2.7149, 2.8460, 2.8735],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0248, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0248, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([-0.0149, -0.0130, -0.0130,  ..., -0.0211, -0.0218, -0.0210])
# Advantages :  tensor([0.5267, 0.7056, 0.7131,  ..., 3.3959, 3.4454, 3.5017])
# Surrogate Loss:  tensor([0.5267, 0.7056, 0.7131,  ..., 3.3959, 3.4454, 3.5017],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0223, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0223, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0187, -0.0179, -0.0171,  ...,  0.0008,  0.0014,  0.0019])
# Advantages :  tensor([0.6189, 0.6486, 0.6765,  ..., 2.8017, 2.8447, 2.7178])
# Surrogate Loss:  tensor([0.6189, 0.6486, 0.6765,  ..., 2.8017, 2.8447, 2.7178],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0231, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0231, grad_fn=<AbsBackward>)
#  Episode 1000
# Score for elite i  1  is  tensor(0.0245, grad_fn=<MeanBackward0>)
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.2577, -0.2589, -0.2597,  ..., -0.2598, -0.2591, -0.2580])
# Advantages :  tensor([1.2976, 1.3094, 1.3520,  ..., 2.8051, 2.8501, 2.9204])
# Surrogate Loss:  tensor([1.2976, 1.3094, 1.3520,  ..., 2.8051, 2.8501, 2.9204],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2423, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2423, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.2568, -0.2567, -0.2560,  ..., -0.2710, -0.2720, -0.2730])
# Advantages :  tensor([-0.9848, -1.0481, -1.0110,  ...,  2.9045,  2.9791,  3.0554])
# Surrogate Loss:  tensor([-0.9848, -1.0481, -1.0110,  ...,  2.9045,  2.9791,  3.0554],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2440, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2440, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2739, -0.2749, -0.2758,  ..., -0.2485, -0.2485, -0.2478])
# Advantages :  tensor([-0.0560, -0.0475, -0.0377,  ...,  2.6006,  2.5828,  2.7027])
# Surrogate Loss:  tensor([-0.0560, -0.0475, -0.0377,  ...,  2.6006,  2.5828,  2.7027],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2462, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2462, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.2328, -0.2316, -0.2305,  ..., -0.2750, -0.2756, -0.2768])
# Advantages :  tensor([-0.2198, -0.1667, -0.2178,  ...,  3.4071,  3.4372,  3.4450])
# Surrogate Loss:  tensor([-0.2198, -0.1667, -0.2178,  ...,  3.4071,  3.4372,  3.4450],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2452, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2452, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.2779, -0.2784, -0.2789,  ..., -0.2382, -0.2373, -0.2363])
# Advantages :  tensor([-0.1565, -0.2828, -0.3978,  ...,  3.5167,  3.5662,  3.6290])
# Surrogate Loss:  tensor([-0.1565, -0.2828, -0.3978,  ...,  3.5167,  3.5662,  3.6290],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2501, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2501, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2353, -0.2343, -0.2332,  ..., -0.2233, -0.2231, -0.2224])
# Advantages :  tensor([1.1108, 1.1384, 1.1642,  ..., 3.6693, 3.6607, 3.7574])
# Surrogate Loss:  tensor([1.1108, 1.1384, 1.1642,  ..., 3.6693, 3.6607, 3.7574],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2442, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2442, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([-0.2283, -0.2279, -0.2266,  ..., -0.2565, -0.2561, -0.2553])
# Advantages :  tensor([ 0.0457, -0.0370,  0.0343,  ...,  3.8241,  3.8287,  3.8681])
# Surrogate Loss:  tensor([ 0.0457, -0.0370,  0.0343,  ...,  3.8241,  3.8287,  3.8681],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2451, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2451, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([-0.2545, -0.2536, -0.2527,  ..., -0.2507, -0.2497, -0.2488])
# Advantages :  tensor([-0.6963, -0.6686, -0.6201,  ...,  4.1717,  4.0250,  3.8140])
# Surrogate Loss:  tensor([-0.6963, -0.6686, -0.6201,  ...,  4.1717,  4.0250,  3.8140],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2464, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2464, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2483, -0.2475, -0.2469,  ..., -0.2066, -0.2047, -0.2028])
# Advantages :  tensor([0.4366, 0.4590, 0.2726,  ..., 2.9746, 3.0485, 3.1032])
# Surrogate Loss:  tensor([0.4366, 0.4590, 0.2726,  ..., 2.9746, 3.0485, 3.1032],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2471, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2471, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([-0.2474, -0.2465, -0.2457,  ..., -0.2132, -0.2115, -0.2095])
# Advantages :  tensor([0.5514, 0.6054, 0.6342,  ..., 3.2362, 3.3079, 3.2636])
# Surrogate Loss:  tensor([0.5514, 0.6054, 0.6342,  ..., 3.2362, 3.3079, 3.2636],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2452, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2452, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([-0.2076, -0.2059, -0.2040,  ..., -0.2327, -0.2330, -0.2332])
# Advantages :  tensor([0.4316, 0.4614, 0.5309,  ..., 4.0354, 4.0128, 3.9925])
# Surrogate Loss:  tensor([0.4316, 0.4614, 0.5309,  ..., 4.0354, 4.0128, 3.9925],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2436, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2436, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2330, -0.2326, -0.2324,  ..., -0.2071, -0.2057, -0.2043])
# Advantages :  tensor([-7.1855e-03,  9.7741e-04, -3.2865e-02,  ...,  3.5290e+00,
#          3.6164e+00,  3.7044e+00])
# Surrogate Loss:  tensor([-7.1855e-03,  9.7741e-04, -3.2865e-02,  ...,  3.5290e+00,
#          3.6164e+00,  3.7044e+00], grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2444, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2444, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([-0.2264, -0.2270, -0.2272,  ..., -0.2433, -0.2429, -0.2427])
# Advantages :  tensor([-1.1951, -1.2780, -1.3224,  ...,  3.6000,  3.7027,  3.7628])
# Surrogate Loss:  tensor([-1.1951, -1.2780, -1.3224,  ...,  3.6000,  3.7027,  3.7628],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2444, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2444, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([-0.2425, -0.2423, -0.2419,  ..., -0.2508, -0.2515, -0.2523])
# Advantages :  tensor([1.5087, 1.5389, 1.5880,  ..., 2.8189, 2.7612, 2.7043])
# Surrogate Loss:  tensor([1.5087, 1.5389, 1.5880,  ..., 2.8189, 2.7612, 2.7043],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2425, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2425, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.2529, -0.2536, -0.2541,  ..., -0.2642, -0.2638, -0.2624])
# Advantages :  tensor([1.0000, 0.9048, 0.8236,  ..., 3.8484, 3.9539, 3.9041])
# Surrogate Loss:  tensor([1.0000, 0.9048, 0.8236,  ..., 3.8484, 3.9539, 3.9041],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.2403, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.2403, grad_fn=<AbsBackward>)
#  Episode 1000
# Score for elite i  7  is  tensor(0.2451, grad_fn=<MeanBackward0>)
# 0.002 (0.9, 0.999)
# State Values :  tensor([-0.0241, -0.0225, -0.0216,  ..., -0.0170, -0.0181, -0.0190])
# Advantages :  tensor([0.4774, 0.4722, 0.4980,  ..., 3.0454, 2.8877, 2.7044])
# Surrogate Loss:  tensor([0.4774, 0.4722, 0.4980,  ..., 3.0454, 2.8877, 2.7044],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0104, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0104, grad_fn=<AbsBackward>)
#  Episode 100
# State Values :  tensor([-0.0185, -0.0177, -0.0202,  ..., -0.0569, -0.0555, -0.0534])
# Advantages :  tensor([1.6329, 1.6413, 1.4511,  ..., 2.3423, 2.4065, 2.4408])
# Surrogate Loss:  tensor([1.6329, 1.6413, 1.4511,  ..., 2.3423, 2.4065, 2.4408],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0178, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0178, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0518, -0.0487, -0.0466,  ..., -0.0331, -0.0347, -0.0331])
# Advantages :  tensor([-0.5221, -0.5604, -0.5533,  ...,  2.7622,  2.7092,  2.7037])
# Surrogate Loss:  tensor([-0.5221, -0.5604, -0.5533,  ...,  2.7622,  2.7092,  2.7037],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0165, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0165, grad_fn=<AbsBackward>)
#  Episode 200
# State Values :  tensor([-0.0293, -0.0285, -0.0265,  ..., -0.0220, -0.0213, -0.0212])
# Advantages :  tensor([-0.0587, -0.1501, -0.2368,  ...,  2.7484,  2.6705,  2.5826])
# Surrogate Loss:  tensor([-0.0587, -0.1501, -0.2368,  ...,  2.7484,  2.6705,  2.5826],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0130, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0130, grad_fn=<AbsBackward>)
#  Episode 300
# State Values :  tensor([-0.0198, -0.0191, -0.0200,  ..., -0.0055, -0.0035, -0.0019])
# Advantages :  tensor([1.3209, 1.2207, 1.3746,  ..., 2.3714, 2.4450, 2.5133])
# Surrogate Loss:  tensor([1.3209, 1.2207, 1.3746,  ..., 2.3714, 2.4450, 2.5133],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0101, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0101, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0011,  0.0001,  0.0010,  ..., -0.0308, -0.0289, -0.0269])
# Advantages :  tensor([0.2557, 0.3044, 0.3648,  ..., 3.0100, 3.0188, 3.0042])
# Surrogate Loss:  tensor([0.2557, 0.3044, 0.3648,  ..., 3.0100, 3.0188, 3.0042],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0112, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0112, grad_fn=<AbsBackward>)
#  Episode 400
# State Values :  tensor([-0.0700, -0.0693, -0.0666,  ..., -0.0052, -0.0036, -0.0028])
# Advantages :  tensor([0.6872, 0.7582, 0.7176,  ..., 2.2751, 2.2984, 2.3540])
# Surrogate Loss:  tensor([0.6872, 0.7582, 0.7176,  ..., 2.2751, 2.2984, 2.3540],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0128, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0128, grad_fn=<AbsBackward>)
#  Episode 500
# State Values :  tensor([-0.0018, -0.0002, -0.0015,  ..., -0.0300, -0.0311, -0.0291])
# Advantages :  tensor([0.4466, 0.4854, 0.2505,  ..., 3.9505, 4.0202, 4.1106])
# Surrogate Loss:  tensor([0.4466, 0.4854, 0.2505,  ..., 3.9505, 4.0202, 4.1106],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0120, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0120, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0287, -0.0258, -0.0240,  ...,  0.0076,  0.0060,  0.0058])
# Advantages :  tensor([-0.8207, -0.8417, -0.8081,  ...,  2.3434,  2.4031,  2.3924])
# Surrogate Loss:  tensor([-0.8207, -0.8417, -0.8081,  ...,  2.3434,  2.4031,  2.3924],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0142, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0142, grad_fn=<AbsBackward>)
#  Episode 600
# State Values :  tensor([-0.0260, -0.0257, -0.0245,  ...,  0.0156,  0.0137,  0.0141])
# Advantages :  tensor([-0.5578, -0.6473, -0.6883,  ...,  3.1863,  2.9738,  3.0040])
# Surrogate Loss:  tensor([-0.5578, -0.6473, -0.6883,  ...,  3.1863,  2.9738,  3.0040],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0061, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0061, grad_fn=<AbsBackward>)
#  Episode 700
# State Values :  tensor([0.0128, 0.0119, 0.0123,  ..., 0.0149, 0.0144, 0.0147])
# Advantages :  tensor([-1.0482, -1.2268, -1.2359,  ...,  2.5382,  2.5140,  2.5274])
# Surrogate Loss:  tensor([-1.0482, -1.2268, -1.2359,  ...,  2.5382,  2.5140,  2.5274],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0122, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0122, grad_fn=<AbsBackward>)
# State Values :  tensor([ 0.0158,  0.0155,  0.0150,  ..., -0.0131, -0.0103, -0.0076])
# Advantages :  tensor([-0.1114, -0.0601, -0.1363,  ...,  3.8296,  3.9182,  4.0143])
# Surrogate Loss:  tensor([-0.1114, -0.0601, -0.1363,  ...,  3.8296,  3.9182,  4.0143],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0137, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0137, grad_fn=<AbsBackward>)
#  Episode 800
# State Values :  tensor([-0.0335, -0.0316, -0.0323,  ...,  0.0031,  0.0029,  0.0046])
# Advantages :  tensor([0.2752, 0.1651, 0.2049,  ..., 2.8553, 2.7118, 2.8004])
# Surrogate Loss:  tensor([0.2752, 0.1651, 0.2049,  ..., 2.8553, 2.7118, 2.8004],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0161, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0161, grad_fn=<AbsBackward>)
#  Episode 900
# State Values :  tensor([ 0.0063,  0.0079,  0.0089,  ..., -0.0033, -0.0036, -0.0035])
# Advantages :  tensor([-1.0151, -0.9535, -1.0442,  ...,  3.6519,  3.5529,  3.6160])
# Surrogate Loss:  tensor([-1.0151, -0.9535, -1.0442,  ...,  3.6519,  3.5529,  3.6160],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0139, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0139, grad_fn=<AbsBackward>)
# State Values :  tensor([-0.0030, -0.0029, -0.0021,  ..., -0.0456, -0.0436, -0.0455])
# Advantages :  tensor([1.4815, 1.5096, 1.5535,  ..., 2.9079, 2.9302, 3.2122])
# Surrogate Loss:  tensor([1.4815, 1.5096, 1.5535,  ..., 2.9079, 2.9302, 3.2122],
#        grad_fn=<MulBackward0>)
# Surrogate Loss Mean :  tensor(0.0106, grad_fn=<MeanBackward0>)
# Surrogate Loss Absolute Value :  tensor(0.0106, grad_fn=<AbsBackward>)
#  Episode 1000
# Score for elite i  9  is  tensor(0.0128, grad_fn=<MeanBackward0>)
# Elite selected with index  7  and score tensor(0.2451, grad_fn=<MeanBackward0>)

# %%
def play_agent(agent):
    env = gym.make("LunarLander-v2")
    env_record = Monitor(env, './video', force=True)
    observation = env_record.reset()
    last_observation = observation
    r=0
    memory = Memory()
    ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)
    for _ in range(250):
        env_record.render()
        action = ppo.policy_old.act(observation, memory)
        new_observation, reward, done, _ = env_record.step(action)
        r=r+reward
        observation = new_observation

        if(done):
            break
    env_record.close()
    print("Rewards: ",r)

# %%
play_agent(agents[1])
