# %%
import gym
import numpy as np
import torch
import matplotlib.pyplot as plt
import time

# %%
from gym.wrappers import Monitor

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import math
import copy

# %%
class CartPoleAI(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc = nn.Sequential(
                        nn.Linear(4,128, bias=True),
                        nn.ReLU(),
                        nn.Linear(128,2, bias=True),
                        nn.Softmax(dim=1)
                        )

                
        def forward(self, inputs):
            x = self.fc(inputs)
            return x

# %%
def init_weights(m):
    
        # nn.Conv2d weights are of shape [16, 1, 3, 3] i.e. # number of filters, 1, stride, stride
        # nn.Conv2d bias is of shape [16] i.e. # number of filters
        
        # nn.Linear weights are of shape [32, 24336] i.e. # number of input features, number of output features
        # nn.Linear bias is of shape [32] i.e. # number of output features
        
        if ((type(m) == nn.Linear) | (type(m) == nn.Conv2d)):
            torch.nn.init.xavier_uniform(m.weight)
            m.bias.data.fill_(0.00)

# %%
def return_random_agents(num_agents):
    
    agents = []
    for _ in range(num_agents):
        
        agent = CartPoleAI()
        
        for param in agent.parameters():
            param.requires_grad = False
            
        init_weights(agent)
        agents.append(agent)
        
        
    return agents

# %%
def run_agents(agents):
    
    reward_agents = []
    env = gym.make("CartPole-v0")
    
    for agent in agents:
        agent.eval()
    
        observation = env.reset()
        
        r=0
        s=0
        
        for _ in range(250):
            
            inp = torch.tensor(observation).type('torch.FloatTensor').view(1,-1)
            output_probabilities = agent(inp).detach().numpy()[0]
            action = np.random.choice(range(game_actions), 1, p=output_probabilities).item()
            new_observation, reward, done, info = env.step(action)
            r=r+reward
            
            s=s+1
            observation = new_observation

            if(done):
                break

        reward_agents.append(r)        
        #reward_agents.append(s)
        
    
    return reward_agents

# %%
def return_average_score(agent, runs):
    score = 0.
    for i in range(runs):
        score += run_agents([agent])[0]
    return score/runs

# %%
def run_agents_n_times(agents, runs):
    avg_score = []
    for agent in agents:
        avg_score.append(return_average_score(agent,runs))
    return avg_score

# %%
def mutate(agent):

    child_agent = copy.deepcopy(agent)
    
    mutation_power = 0.02 #hyper-parameter, set from https://arxiv.org/pdf/1712.06567.pdf
            
    for param in child_agent.parameters():
    
        if(len(param.shape)==4): #weights of Conv2D

            for i0 in range(param.shape[0]):
                for i1 in range(param.shape[1]):
                    for i2 in range(param.shape[2]):
                        for i3 in range(param.shape[3]):
                            
                            param[i0][i1][i2][i3]+= mutation_power * np.random.randn()
                                
                                    

        elif(len(param.shape)==2): #weights of linear layer
            for i0 in range(param.shape[0]):
                for i1 in range(param.shape[1]):
                    
                    param[i0][i1]+= mutation_power * np.random.randn()
                        

        elif(len(param.shape)==1): #biases of linear layer or conv layer
            for i0 in range(param.shape[0]):
                
                param[i0]+=mutation_power * np.random.randn()

    return child_agent

# %%
def return_children(agents, sorted_parent_indexes, elite_index):
    
    children_agents = []
    
    #first take selected parents from sorted_parent_indexes and generate N-1 children
    for i in range(len(agents)-1):
        
        selected_agent_index = sorted_parent_indexes[np.random.randint(len(sorted_parent_indexes))]
        children_agents.append(mutate(agents[selected_agent_index]))

    #now add one elite
    elite_child = add_elite(agents, sorted_parent_indexes, elite_index)
    children_agents.append(elite_child)
    elite_index=len(children_agents)-1 #it is the last one
    
    return children_agents, elite_index

# %%
def add_elite(agents, sorted_parent_indexes, elite_index=None, only_consider_top_n=10):
    
    candidate_elite_index = sorted_parent_indexes[:only_consider_top_n]
    
    if(elite_index is not None):
        candidate_elite_index = np.append(candidate_elite_index,[elite_index])
        
    top_score = None
    top_elite_index = None
    
    for i in candidate_elite_index:
        score = return_average_score(agents[i],runs=5)
        print("Score for elite i ", i, " is ", score)
        
        if(top_score is None):
            top_score = score
            top_elite_index = i
        elif(score > top_score):
            top_score = score
            top_elite_index = i
            
    print("Elite selected with index ",top_elite_index, " and score", top_score)
    
    child_agent = copy.deepcopy(agents[top_elite_index])
    return child_agent

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    return np.exp(x) / np.sum(np.exp(x), axis=0)

# %%
game_actions = 2 #2 actions possible: left or right

#disable gradients as we will not use them
torch.set_grad_enabled(False)

# initialize N number of agents
num_agents = 500
agents = return_random_agents(num_agents)

# How many top agents to consider as parents
top_limit = 20

# run evolution until X generations
generations = 20

elite_index = None
n=[]

for generation in range(generations):

    # return rewards of agents
    rewards = run_agents_n_times(agents, 1) #return average of 3 runs later
    #print(rewards)
    #sort by rewards
    sorted_parent_indexes = np.argsort(rewards)[::-1][:top_limit] #reverses and gives top values (argsort sorts by ascending by default) https://stackoverflow.com/questions/16486252/is-it-possible-to-use-argsort-in-descending-order
    print("")
    print("")
    top_rewards = []
    
    for best_parent in sorted_parent_indexes:
        top_rewards.append(rewards[best_parent])
    
    print("Generation ", generation, " | Mean rewards: ", np.mean(rewards), " | Mean of top 5: ",np.mean(top_rewards[:5]))
    #print(rewards)
    print("Top ",top_limit," scores", sorted_parent_indexes)
    print("Rewards for top: ",top_rewards)
    
    n.append(np.mean(rewards))
    
    # setup an empty list for containing children agents
    children_agents, elite_index = return_children(agents, sorted_parent_indexes, elite_index)

    # kill all agents, and replace them with their children
    agents = children_agents
x=np.arange(generations)
plt.plot(x,n)
plt.title('Improvement of Mean Rewards in increasing Generations(Training)')
plt.ylabel('Mean Rewards')
plt.xlabel('Generations')
plt.show()
# Out:
# Generation  0  | Mean rewards:  21.566  | Mean of top 5:  61.2
# Top  20  scores [478  73 260  82 358 329 290 324 232 298 419 231 200 311 220 351  44 132
#  463 269]
# Rewards for top:  [64.0, 64.0, 60.0, 60.0, 58.0, 57.0, 55.0, 54.0, 53.0, 52.0, 52.0, 51.0, 51.0, 51.0, 51.0, 51.0, 50.0, 50.0, 49.0, 49.0]
# Score for elite i  478  is  21.8
# Score for elite i  73  is  16.4
# Score for elite i  260  is  21.4
# Score for elite i  82  is  19.8
# Score for elite i  358  is  20.2
# Score for elite i  329  is  25.0
# Score for elite i  290  is  17.2
# Score for elite i  324  is  21.4
# Score for elite i  232  is  17.2
# Score for elite i  298  is  17.0
# Elite selected with index  329  and score 25.0
#
#
# Generation  1  | Mean rewards:  23.368  | Mean of top 5:  85.0
# Top  20  scores [463 365  52  69  59 171 115 485 343 248 153 289 468 356 315 438  24 242
#   17  73]
# Rewards for top:  [100.0, 94.0, 90.0, 71.0, 70.0, 65.0, 64.0, 63.0, 62.0, 62.0, 60.0, 60.0, 59.0, 59.0, 57.0, 57.0, 57.0, 56.0, 56.0, 51.0]
# Score for elite i  463  is  23.8
# Score for elite i  365  is  29.2
# Score for elite i  52  is  24.4
# Score for elite i  69  is  20.6
# Score for elite i  59  is  23.0
# Score for elite i  171  is  20.6
# Score for elite i  115  is  26.4
# Score for elite i  485  is  18.0
# Score for elite i  343  is  26.0
# Score for elite i  248  is  23.4
# Score for elite i  499  is  26.4
# Elite selected with index  365  and score 29.2
#
#
# Generation  2  | Mean rewards:  24.23  | Mean of top 5:  86.4
# Top  20  scores [310 195  83 375   7 301  41 104 309 464 245 416 344 418 216 252 126 494
#  445 101]
# Rewards for top:  [92.0, 90.0, 87.0, 86.0, 77.0, 75.0, 74.0, 71.0, 70.0, 69.0, 63.0, 61.0, 61.0, 61.0, 60.0, 58.0, 57.0, 56.0, 56.0, 56.0]
# Score for elite i  310  is  23.2
# Score for elite i  195  is  19.8
# Score for elite i  83  is  24.6
# Score for elite i  375  is  16.8
# Score for elite i  7  is  28.8
# Score for elite i  301  is  28.6
# Score for elite i  41  is  29.0
# Score for elite i  104  is  28.6
# Score for elite i  309  is  25.4
# Score for elite i  464  is  28.0
# Score for elite i  499  is  24.6
# Elite selected with index  41  and score 29.0
#
#
# Generation  3  | Mean rewards:  23.992  | Mean of top 5:  88.0
# Top  20  scores [130 254  27 373 170 134 420 250 344 355 153 469 382 363   5 174 113  40
#  298 141]
# Rewards for top:  [100.0, 95.0, 84.0, 81.0, 80.0, 79.0, 78.0, 77.0, 75.0, 66.0, 65.0, 65.0, 62.0, 61.0, 59.0, 59.0, 56.0, 55.0, 53.0, 53.0]
# Score for elite i  130  is  21.0
# Score for elite i  254  is  15.4
# Score for elite i  27  is  31.4
# Score for elite i  373  is  22.6
# Score for elite i  170  is  27.6
# Score for elite i  134  is  19.2
# Score for elite i  420  is  17.2
# Score for elite i  250  is  26.0
# Score for elite i  344  is  23.2
# Score for elite i  355  is  22.2
# Score for elite i  499  is  21.2
# Elite selected with index  27  and score 31.4
#
#
# Generation  4  | Mean rewards:  25.558  | Mean of top 5:  81.6
# Top  20  scores [118 121 185 328 221 489  50 322 437 123   6 151  30 152 261 105 176 423
#  339 295]
# Rewards for top:  [100.0, 82.0, 81.0, 73.0, 72.0, 72.0, 71.0, 70.0, 69.0, 69.0, 68.0, 66.0, 64.0, 64.0, 63.0, 63.0, 61.0, 60.0, 60.0, 60.0]
# Score for elite i  118  is  29.4
# Score for elite i  121  is  43.8
# Score for elite i  185  is  23.2
# Score for elite i  328  is  24.2
# Score for elite i  221  is  40.6
# Score for elite i  489  is  28.6
# Score for elite i  50  is  19.4
# Score for elite i  322  is  26.6
# Score for elite i  437  is  40.6
# Score for elite i  123  is  25.0
# Score for elite i  499  is  25.4
# Elite selected with index  121  and score 43.8
#
#
# Generation  5  | Mean rewards:  26.46  | Mean of top 5:  93.2
# Top  20  scores [369 189 283 119 170 270 354 414 265 274 306 115 230 264 381 211 318 455
#  499 432]
# Rewards for top:  [135.0, 87.0, 86.0, 81.0, 77.0, 72.0, 70.0, 68.0, 66.0, 66.0, 65.0, 65.0, 65.0, 62.0, 62.0, 61.0, 61.0, 60.0, 57.0, 57.0]
# Score for elite i  369  is  26.2
# Score for elite i  189  is  28.6
# Score for elite i  283  is  30.0
# Score for elite i  119  is  35.8
# Score for elite i  170  is  32.4
# Score for elite i  270  is  36.2
# Score for elite i  354  is  48.8
# Score for elite i  414  is  32.0
# Score for elite i  265  is  19.6
# Score for elite i  274  is  23.2
# Score for elite i  499  is  45.2
# Elite selected with index  354  and score 48.8
#
#
# Generation  6  | Mean rewards:  27.726  | Mean of top 5:  94.6
# Top  20  scores [332 356  24 348  83 228 386 432 114 278  13  97 239 110 224 456 103   5
#  175 181]
# Rewards for top:  [106.0, 104.0, 95.0, 86.0, 82.0, 74.0, 73.0, 72.0, 72.0, 71.0, 70.0, 69.0, 64.0, 64.0, 63.0, 62.0, 61.0, 61.0, 61.0, 59.0]
# Score for elite i  332  is  21.2
# Score for elite i  356  is  24.6
# Score for elite i  24  is  54.0
# Score for elite i  348  is  18.6
# Score for elite i  83  is  23.2
# Score for elite i  228  is  27.4
# Score for elite i  386  is  18.4
# Score for elite i  432  is  22.6
# Score for elite i  114  is  15.0
# Score for elite i  278  is  57.8
# Score for elite i  499  is  28.0
# Elite selected with index  278  and score 57.8
#
#
# Generation  7  | Mean rewards:  30.942  | Mean of top 5:  105.2
# Top  20  scores [476 260 153 439 470 201 213 391 185 152  67 423 478 247 396 226 229 375
#   37  82]
# Rewards for top:  [132.0, 110.0, 101.0, 97.0, 86.0, 83.0, 79.0, 78.0, 78.0, 78.0, 78.0, 77.0, 76.0, 75.0, 75.0, 72.0, 70.0, 69.0, 68.0, 68.0]
# Score for elite i  476  is  47.6
# Score for elite i  260  is  28.0
# Score for elite i  153  is  22.4
# Score for elite i  439  is  30.8
# Score for elite i  470  is  33.4
# Score for elite i  201  is  36.8
# Score for elite i  213  is  27.0
# Score for elite i  391  is  38.8
# Score for elite i  185  is  25.6
# Score for elite i  152  is  29.6
# Score for elite i  499  is  23.4
# Elite selected with index  476  and score 47.6
#
#
# Generation  8  | Mean rewards:  34.344  | Mean of top 5:  111.6
# Top  20  scores [206  90 274 325 470  89 449 272 279 209 419 240 213   2 314 264 160 226
#   50 110]
# Rewards for top:  [133.0, 112.0, 112.0, 105.0, 96.0, 93.0, 90.0, 90.0, 88.0, 87.0, 84.0, 82.0, 82.0, 81.0, 80.0, 79.0, 77.0, 77.0, 76.0, 76.0]
# Score for elite i  206  is  23.2
# Score for elite i  90  is  27.0
# Score for elite i  274  is  24.2
# Score for elite i  325  is  39.8
# Score for elite i  470  is  49.6
# Score for elite i  89  is  27.8
# Score for elite i  449  is  47.2
# Score for elite i  272  is  24.8
# Score for elite i  279  is  55.2
# Score for elite i  209  is  28.0
# Score for elite i  499  is  55.2
# Elite selected with index  279  and score 55.2
#
#
# Generation  9  | Mean rewards:  36.502  | Mean of top 5:  103.8
# Top  20  scores [288 148 244 237  47 135 221 140  14 396 381 319 499  66 367 201  71 172
#  440 461]
# Rewards for top:  [119.0, 109.0, 100.0, 96.0, 95.0, 95.0, 95.0, 92.0, 91.0, 91.0, 91.0, 88.0, 87.0, 87.0, 85.0, 85.0, 84.0, 83.0, 83.0, 82.0]
# Score for elite i  288  is  40.6
# Score for elite i  148  is  32.2
# Score for elite i  244  is  29.2
# Score for elite i  237  is  32.2
# Score for elite i  47  is  32.0
# Score for elite i  135  is  47.0
# Score for elite i  221  is  36.0
# Score for elite i  140  is  34.8
# Score for elite i  14  is  32.4
# Score for elite i  396  is  37.2
# Score for elite i  499  is  37.6
# Elite selected with index  135  and score 47.0
#
#
# Generation  10  | Mean rewards:  34.71  | Mean of top 5:  114.8
# Top  20  scores [ 90 209 259 132 113 488 203 225 379 361 269 305 241 268 238 316 397 131
#  275 207]
# Rewards for top:  [148.0, 116.0, 114.0, 99.0, 97.0, 93.0, 91.0, 83.0, 83.0, 81.0, 80.0, 80.0, 79.0, 78.0, 78.0, 77.0, 76.0, 76.0, 75.0, 73.0]
# Score for elite i  90  is  27.2
# Score for elite i  209  is  37.2
# Score for elite i  259  is  27.6
# Score for elite i  132  is  20.6
# Score for elite i  113  is  38.6
# Score for elite i  488  is  31.4
# Score for elite i  203  is  27.0
# Score for elite i  225  is  36.8
# Score for elite i  379  is  31.0
# Score for elite i  361  is  20.4
# Score for elite i  499  is  76.8
# Elite selected with index  499  and score 76.8
#
#
# Generation  11  | Mean rewards:  36.132  | Mean of top 5:  126.0
# Top  20  scores [237 405 360  22 319 272 214 251 333 314 229 477  40  69 297  13 435 238
#  309 256]
# Rewards for top:  [144.0, 130.0, 122.0, 118.0, 116.0, 112.0, 103.0, 99.0, 95.0, 94.0, 93.0, 92.0, 91.0, 90.0, 88.0, 86.0, 85.0, 84.0, 84.0, 83.0]
# Score for elite i  237  is  41.4
# Score for elite i  405  is  41.0
# Score for elite i  360  is  42.6
# Score for elite i  22  is  34.6
# Score for elite i  319  is  45.0
# Score for elite i  272  is  21.6
# Score for elite i  214  is  50.8
# Score for elite i  251  is  28.2
# Score for elite i  333  is  35.2
# Score for elite i  314  is  36.0
# Score for elite i  499  is  37.2
# Elite selected with index  214  and score 50.8
#
#
# Generation  12  | Mean rewards:  35.986  | Mean of top 5:  113.2
# Top  20  scores [144 336 499 131 340 459 391  30 375 186 400 397 125 154  80 433  17 358
#  258 342]
# Rewards for top:  [128.0, 123.0, 117.0, 101.0, 97.0, 96.0, 95.0, 95.0, 95.0, 94.0, 93.0, 93.0, 91.0, 90.0, 86.0, 85.0, 84.0, 82.0, 80.0, 80.0]
# Score for elite i  144  is  31.4
# Score for elite i  336  is  45.2
# Score for elite i  499  is  46.6
# Score for elite i  131  is  47.6
# Score for elite i  340  is  21.0
# Score for elite i  459  is  49.8
# Score for elite i  391  is  30.4
# Score for elite i  30  is  29.4
# Score for elite i  375  is  40.2
# Score for elite i  186  is  32.8
# Score for elite i  499  is  36.2
# Elite selected with index  459  and score 49.8
#
#
# Generation  13  | Mean rewards:  35.74  | Mean of top 5:  128.2
# Top  20  scores [ 66 347 262 332 378  24 407 214  18 318 189 251 377 101 373   4 180  26
#   72 191]
# Rewards for top:  [157.0, 145.0, 130.0, 105.0, 104.0, 103.0, 97.0, 95.0, 93.0, 91.0, 89.0, 88.0, 88.0, 85.0, 84.0, 84.0, 84.0, 82.0, 82.0, 81.0]
# Score for elite i  66  is  41.8
# Score for elite i  347  is  47.2
# Score for elite i  262  is  21.2
# Score for elite i  332  is  42.8
# Score for elite i  378  is  30.4
# Score for elite i  24  is  17.6
# Score for elite i  407  is  25.8
# Score for elite i  214  is  33.6
# Score for elite i  18  is  22.4
# Score for elite i  318  is  48.0
# Score for elite i  499  is  39.2
# Elite selected with index  318  and score 48.0
#
#
# Generation  14  | Mean rewards:  38.874  | Mean of top 5:  142.4
# Top  20  scores [355  79  75 303 199 249 248 445 346 232 450 122  45 285 349 318 462  38
#  134 304]
# Rewards for top:  [185.0, 137.0, 135.0, 128.0, 127.0, 124.0, 108.0, 107.0, 106.0, 106.0, 104.0, 103.0, 95.0, 95.0, 92.0, 88.0, 88.0, 87.0, 87.0, 86.0]
# Score for elite i  355  is  30.0
# Score for elite i  79  is  34.4
# Score for elite i  75  is  36.8
# Score for elite i  303  is  36.2
# Score for elite i  199  is  44.6
# Score for elite i  249  is  58.6
# Score for elite i  248  is  31.4
# Score for elite i  445  is  45.0
# Score for elite i  346  is  20.2
# Score for elite i  232  is  49.4
# Score for elite i  499  is  38.0
# Elite selected with index  249  and score 58.6
#
#
# Generation  15  | Mean rewards:  37.624  | Mean of top 5:  125.6
# Top  20  scores [ 27 499 427 413  47  13 220  53 448 144  15 174 405 171 404 430 431 302
#  458 128]
# Rewards for top:  [145.0, 131.0, 126.0, 114.0, 112.0, 110.0, 108.0, 107.0, 103.0, 101.0, 95.0, 95.0, 93.0, 91.0, 90.0, 89.0, 84.0, 84.0, 84.0, 84.0]
# Score for elite i  27  is  29.8
# Score for elite i  499  is  32.4
# Score for elite i  427  is  52.2
# Score for elite i  413  is  48.8
# Score for elite i  47  is  35.8
# Score for elite i  13  is  40.6
# Score for elite i  220  is  42.2
# Score for elite i  53  is  33.6
# Score for elite i  448  is  31.0
# Score for elite i  144  is  60.4
# Score for elite i  499  is  36.0
# Elite selected with index  144  and score 60.4
#
#
# Generation  16  | Mean rewards:  38.186  | Mean of top 5:  129.0
# Top  20  scores [363 100 104 209   1 270 488  35 315 215 441  38   7  11  51 133  87 386
#   18 341]
# Rewards for top:  [162.0, 132.0, 119.0, 116.0, 116.0, 110.0, 106.0, 101.0, 101.0, 97.0, 95.0, 93.0, 91.0, 91.0, 89.0, 88.0, 86.0, 85.0, 83.0, 82.0]
# Score for elite i  363  is  36.8
# Score for elite i  100  is  40.2
# Score for elite i  104  is  46.2
# Score for elite i  209  is  41.4
# Score for elite i  1  is  66.6
# Score for elite i  270  is  33.6
# Score for elite i  488  is  43.4
# Score for elite i  35  is  48.2
# Score for elite i  315  is  45.8
# Score for elite i  215  is  51.6
# Score for elite i  499  is  36.0
# Elite selected with index  1  and score 66.6
#
#
# Generation  17  | Mean rewards:  37.07  | Mean of top 5:  108.0
# Top  20  scores [ 61   3 470 206 491 304 321 126 168 398  87  75  38 152 286  17 403 164
#  467 352]
# Rewards for top:  [126.0, 110.0, 108.0, 102.0, 94.0, 94.0, 93.0, 91.0, 90.0, 89.0, 89.0, 86.0, 85.0, 84.0, 83.0, 83.0, 81.0, 81.0, 81.0, 81.0]
# Score for elite i  61  is  28.2
# Score for elite i  3  is  42.8
# Score for elite i  470  is  50.0
# Score for elite i  206  is  34.4
# Score for elite i  491  is  35.6
# Score for elite i  304  is  47.8
# Score for elite i  321  is  50.0
# Score for elite i  126  is  50.2
# Score for elite i  168  is  38.8
# Score for elite i  398  is  40.4
# Score for elite i  499  is  59.2
# Elite selected with index  499  and score 59.2
#
#
# Generation  18  | Mean rewards:  37.378  | Mean of top 5:  116.2
# Top  20  scores [369  72 237  73 266 387 105 136 301 407  43 161 113  64 362 442  88  13
#  404 275]
# Rewards for top:  [140.0, 120.0, 115.0, 103.0, 103.0, 101.0, 98.0, 98.0, 96.0, 93.0, 93.0, 92.0, 91.0, 88.0, 87.0, 86.0, 86.0, 85.0, 84.0, 84.0]
# Score for elite i  369  is  28.8
# Score for elite i  72  is  51.6
# Score for elite i  237  is  66.8
# Score for elite i  73  is  38.8
# Score for elite i  266  is  46.4
# Score for elite i  387  is  41.0
# Score for elite i  105  is  38.0
# Score for elite i  136  is  39.4
# Score for elite i  301  is  35.4
# Score for elite i  407  is  36.2
# Score for elite i  499  is  58.2
# Elite selected with index  237  and score 66.8
#
#
# Generation  19  | Mean rewards:  39.434  | Mean of top 5:  143.2
# Top  20  scores [ 34 237 354 164  75 406 196  54 147 250 441 465 178 453 185 319 298 170
#  207  11]
# Rewards for top:  [160.0, 159.0, 140.0, 137.0, 120.0, 110.0, 108.0, 106.0, 106.0, 105.0, 104.0, 103.0, 100.0, 100.0, 95.0, 93.0, 93.0, 92.0, 92.0, 92.0]
# Score for elite i  34  is  51.2
# Score for elite i  237  is  44.8
# Score for elite i  354  is  31.2
# Score for elite i  164  is  50.4
# Score for elite i  75  is  40.8
# Score for elite i  406  is  25.6
# Score for elite i  196  is  42.2
# Score for elite i  54  is  25.4
# Score for elite i  147  is  38.2
# Score for elite i  250  is  31.4
# Score for elite i  499  is  41.0
# Elite selected with index  34  and score 51.2

# %%
def play_agent(agent):
        env = gym.make("CartPole-v0")
        
        env_record = Monitor(env, './video', force=True)
        observation = env_record.reset()
        last_observation = observation
        r=0
        for _ in range(250):
            env_record.render()
            inp = torch.tensor(observation).type('torch.FloatTensor').view(1,-1)
             =output_probabilities agent(inp).detach().numpy()[0]
            action = np.random.choice(range(game_actions), 1, p=output_probabilities).item()
            new_observation, reward, done, info = env_record.step(action)
            r=r+reward
            observation = new_observation

            if(done):
                break

        env_record.close()
        print("Rewards: ",r)

# %%
play_agent(agents[2])
# Out:
# Rewards:  141.0
